# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv("example.env")

NYT_API_KEY = os.getenv("NYT_API_KEY")
TMDB_API_KEY = os.getenv("TMDB_API_KEY")

# Check that the environment variables were read successfully
#print(NYT_API_KEY  + " " + TMDB_API_KEY)
# Out:
# Q8dLYw6OWoveUcxOSJLtmdq9pYqLEWOL 8fc3261d2c678a992a896f5680edebbe

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = f"{url}api-key={NYT_API_KEY}&fq={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}"

# %%
def get_data(url):

    try:
        response = requests.get(url)
        if response.status_code == 200:
            return response
        else:
            raise Exception(f"Error getting data from {url} Response code: {response.status_code} Error: {response.text}")
    except Exception as e:
        raise Exception(f"Error getting data from {url} Error: {e}")

# %%
# Create an empty list to store the reviews

reviews_list = []

# loop through pages 0-19
for page in range(0, 20):

    # create query with a page number
    # API results show 10 articles at a time
    # so each page has 10 results
    query_url = f"{url}api-key={NYT_API_KEY}&fq={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}&page={page}"
 
    # Make a "GET" request and retrieve the JSON
    try:
        response = requests.get(query_url)
        response = response.json()
    except Exception as e:
        print(f"Error getting data from {query_url} Error: {e}")
        break

    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)

    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        for review in response["response"]["docs"]:
            reviews_list.append(review)

        # Print the page that was just retrieved
        print(f"Retrieved page {page}")


        # Print the page number that had no results then break from the loop
        if len(response["response"]["docs"]) == 0:
            print(f"Page {page} returned no results")
            break
    except Exception as e:
        print(f"An error occurred when retrieving NYT data. Error: {e}.")
# Out:
# Retrieved page 0
# Retrieved page 1
# Retrieved page 2
# Retrieved page 3
# Retrieved page 4
# Retrieved page 5
# Retrieved page 6
# Retrieved page 7
# Retrieved page 8
# Retrieved page 9
# Retrieved page 10
# Retrieved page 11
# Retrieved page 12
# Retrieved page 13
# Retrieved page 14
# Retrieved page 15
# Retrieved page 16
# Retrieved page 17
# Retrieved page 18
# Retrieved page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
# ...

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_list)
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# ...

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early

# I could have done it this way but I saw issues with some titles
# reviews_df["title"] = reviews_df["headline.main"].str.extract(r"\u2018(.*)\u2019 Review")

def get_title(title):
    try:
        start_position = title.find("\u2018") + 1
        # find last occurence of \u2019
        end_position = title.rfind("\u2019")
        return title[start_position:end_position]
    except Exception as e:
        print(f"Error getting title from {title} Error: {e}")
        return None
    
reviews_df["title"] = reviews_df["headline.main"].apply(get_title)

# show title column
# reviews_df["title"].head()
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# ...

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df["keywords"] = reviews_df["keywords"].apply(extract_keywords)
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;persons: Kapur, Shekhar;person...
# ...

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
title_list = reviews_df["title"].to_list()
title_list[:5]
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + TMDB_API_KEY

# %%
# Create an empty list to store the results
tmdb_movies_list = []


# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1


# Loop through the titles
for title in title_list:

    # Check if we need to sleep before making a request
    if request_counter % 50 == 0:
        print("Sleeping for 10 seconds")
        time.sleep(10)


    # Add 1 to the request counter
    request_counter += 1

    
    # Perform a "GET" request for The Movie Database
    # Use the title in the query
    try:
        query_url = url + title + tmdb_key_string
        response = get_data(query_url)
        response = response.json()
    except Exception as e:
        print(f"Error getting data from {query_url} Error: {e}")
        break

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:

        # Get movie id
        movie_id = response["results"][0]["id"]

        # Make a request for a the full movie details
        # Use the movie id in the query
        query_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={TMDB_API_KEY}"


        # Execute "GET" request with url
        response = get_data(query_url)
        response = response.json()

        
        # Extract the genre names into a list
        genre_list = []
        for genre in response["genres"]:
            genre_list.append(genre["name"])


        # Extract the spoken_languages' English name into a list
        spoken_languages_list = []
        for language in response["spoken_languages"]:
            spoken_languages_list.append(language["english_name"])


        # Extract the production_countries' name into a list
        production_countries_list = []
        for country in response["production_countries"]:
            production_countries_list.append(country["name"])


        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        tmdb_movies_list.append(
            {
                "title": response['title'],
                "original_title": response['original_title'],
                "budget": response['budget'],
                "genre": genre_list,
                "language": response['original_language'],
                "spoken_languages": spoken_languages_list,
                "homepage": response['homepage'],
                "overview": response['overview'],
                "popularity": response['popularity'],
                "runtime": response['runtime'],
                "revenue": response['revenue'],
                "release_date": response['release_date'],
                "vote_average": response['vote_average'],
                "vote_count": response['vote_count'],
                "production_countries": production_countries_list
            }
        )
        
        # Print out the title that was found
        print(f"Found {title}")
    except Exception as e:
        print(f"Didn't find {title}.")
# Out:
# Found The Attachment Diaries
# Found What’s Love Got to Do With It?
# Found You Can Live Forever
# Found A Tourist’s Guide to Love
# Found Other People’s Children
# Found One True Loves
# Found The Lost Weekend: A Love Story
# Found A Thousand and One
# Found Your Place or Mine
# Found Love in the Time of Fentanyl
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Didn't find About Fate’ Review: Love the One You.
# Found Waiting for Bojangles
# Found I Love My Dad
# Found A Love Song
# Found Alone Together
# Found Art of Love
# Found The Wheel
# Didn't find Thor: Love and Thunder’ Review: A God.
# Found Both Sides of the Blade
# Found Fire of Love
# Found Love & Gelato
# Found Stay Prayed Up
# Didn't find Benediction’ Review: A Poet.
# Found Dinner in America
# Found In a New York Minute
# ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list[:5], indent=4))
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "genre": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "language": "es",
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 0.982,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 4.0,
#         "vote_count": 2,
# ...

# %%
# Convert the results to a DataFrame
tmdb_movies_df = pd.DataFrame(tmdb_movies_list)
tmdb_movies_df.head()
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1  What's Love Got to Do with It?  What's Love Got to Do with It?       0
# 2            You Can Live Forever            You Can Live Forever       0
# 3       A Tourist's Guide to Love       A Tourist's Guide to Love       0
# 4         Other People's Children          Les Enfants des autres       0
#
#                                 genre language             spoken_languages  \
# 0  [Drama, Mystery, Thriller, Horror]       es                    [Spanish]
# 1                   [Romance, Comedy]       en  [English, Urdu, Portuguese]
# 2                    [Drama, Romance]       en            [English, French]
# 3                   [Romance, Comedy]       en        [English, Vietnamese]
# 4                     [Drama, Comedy]       fr            [English, French]
#
#                                             homepage  \
# 0
# 1
# ...

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
tmdb_movies_df.head()
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1  What's Love Got to Do with It?  What's Love Got to Do with It?       0
# 2            You Can Live Forever            You Can Live Forever       0
# 3       A Tourist's Guide to Love       A Tourist's Guide to Love       0
# 4         Other People's Children          Les Enfants des autres       0
#
#                                 genre language             spoken_languages  \
# 0  [Drama, Mystery, Thriller, Horror]       es                    [Spanish]
# 1                   [Romance, Comedy]       en  [English, Urdu, Portuguese]
# 2                    [Drama, Romance]       en            [English, French]
# 3                   [Romance, Comedy]       en        [English, Vietnamese]
# 4                     [Drama, Comedy]       fr            [English, French]
#
#                                             homepage  \
# 0
# 1
# ...

# %%
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;persons: Kapur, Shekhar;person...
# ...

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
# Use an inner join to only include movies that are in both DataFrames
merged_df = pd.merge(reviews_df, tmdb_movies_df, on="title", how="inner")

# Columns hidden because there are so many. Did this to show ones I was interested in
#merged_df[["title", "genre", "spoken_languages", "production_countries"]].head()

merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/13/movies/one-...
# 3  https://www.nytimes.com/2023/04/13/movies/the-...
# 4  https://www.nytimes.com/2023/03/30/movies/a-th...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 3  There’s not much Lennon music heard in this do...  The New York Times
# 4  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: You Can Live F...
# ...

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["genre", "spoken_languages", "production_countries"]


# Create a list of characters to remove
characters_to_remove = ["[", "]", "'"]


# Loop through the list of columns to fix
for column in columns_to_fix:

    # Convert the column to type 'str'
    merged_df[column] = merged_df[column].astype(str)


    # Loop through characters to remove
    for character in characters_to_remove:

        # Remove the character
        merged_df[column] = merged_df[column].str.replace(character, "", regex=False)


# Display the fixed Columns along with title
#merged_df[["title", "genre", "spoken_languages", "production_countries"]].head()

merged_df.head()
# Out:
#                             title                             genre  \
# 0          The Attachment Diaries  Drama, Mystery, Thriller, Horror
# 1            You Can Live Forever                    Drama, Romance
# 2                  One True Loves            Romance, Drama, Comedy
# 3  The Lost Weekend: A Love Story                       Documentary
# 4              A Thousand and One                      Drama, Crime
#
#                spoken_languages               production_countries
# 0                       Spanish                          Argentina
# 1               English, French   Canada, United States of America
# 2                       English  Germany, United States of America
# 3                       English           United States of America
# 4  English, Spanish, Portuguese           United States of America

# %%
# Drop "byline.person" column
merged_df = merged_df.drop(columns=["byline.person"])

# %%
# Delete duplicate rows and reset index
merged_df = merged_df.drop_duplicates().reset_index(drop=True)

# %%
# Export data to CSV without the index
merged_df.to_csv("output/nyt_movie_reviews.csv", index=False)
